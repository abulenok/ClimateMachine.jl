# %% [markdown]
# # Mode-1 internal wave reflection
#
# This example simulates the propagation of a mode-1 internal wave
# using the `ClimateMachine.Ocean` subcomponent to solve the hydrostatic
# Boussinesq equations.
#
# First we `ClimateMachine.init()`.

# %%
using ClimateMachine

ClimateMachine.init()

# %% [markdown]
# # Domain setup
#
# We formulate a non-dimension problem in a Cartesian domain with oceanic anisotropy,

# %%
using ClimateMachine.Ocean.Domains

domain = RectangularDomain(
    Ne = (32, 1, 4),
    Np = 4,
    x = (-128, 128),
    y = (-128, 128),
    z = (-1, 0),
    periodicity = (false, false, false),
)
# Out:
# RectangularDomain{Float64}
#     Np = 4, Ne = (x = 32, y = 1, z = 4)
#     L = (x = 256.0, y = 256.0, z = 1.0)

# %% [markdown]
# # Parameters
#
# We choose parameters appropriate for a hydrostatic internal wave,

# %% [markdown]
# Non-dimensional internal wave parameters

# %%
f = 1  # Coriolis
N = 10 # Buoyancy frequency
# Out:
# 10

# %% [markdown]
# Note that the validity of the hydrostatic approximation requires
# small aspect ratio motions with ``k / m \\ll 1``.
# The hydrostatic dispersion relation for inertia-gravity waves then implies that

# %%
λ = 8      # horizontal wave-length
k = 2π / λ # horizontal wavenumber
m = π

ω² = f^2 + N^2 * k^2 / m^2 # and

ω = √(ω²)
# Out:
# 2.692582403567252

# %% [markdown]
# # Internal wave initial condition
#
# We impose modest gravitational acceleration to render time-stepping feasible,

# %%
using CLIMAParameters: AbstractEarthParameterSet, Planet
struct NonDimensionalParameters <: AbstractEarthParameterSet end

Planet.grav(::NonDimensionalParameters) = 256.0

# %% [markdown]
# we'd like to use `θ` as a buoyancy variable, which requires
# setting the thermal expansion coefficient ``αᵀ`` to

# %%
g = Planet.grav(NonDimensionalParameters())

αᵀ = 1 / g
# Out:
# 0.00390625

# %% [markdown]
# We then use the "polarization relations" for vertically-standing, horizontally-
# propagating hydrostatic internal waves to initialze two wave packets.
# The hydrostatic polarization relations require
#
# $$
# \begin{gather}
# (∂_t^2 + f^2) u = - ∂_x ∂_t p
# ∂_t v = - f u
# b = ∂_z p
# \end{gather}
# $$
#
# Thus given ``p = \cos (k x - ω t) \cos (m z)``, we find

# %%
δ = domain.L.x / 15
a(x) = 1e-6 * exp(-x^2 / 2 * δ^2)

ũ(x, z, t) = +a(x) * ω * sin(k * x - ω * t) * cos(m * z)
ṽ(x, z, t) = -a(x) * f * cos(k * x - ω * t) * cos(m * z)
θ̃(x, z, t) = -a(x) * m / k * (ω^2 - f^2) * sin(k * x - ω * t) * sin(m * z)

uᵢ(x, y, z) = ũ(x, z, 0)
vᵢ(x, y, z) = ṽ(x, z, 0)
θᵢ(x, y, z) = θ̃(x, z, 0) + N^2 * z

using ClimateMachine.Ocean.OceanProblems: InitialConditions

initial_conditions = InitialConditions(u = uᵢ, v = vᵢ, θ = θᵢ)
# Out:
# ClimateMachine.Ocean.OceanProblems.InitialConditions{typeof(Main.##441.uᵢ), typeof(Main.##441.vᵢ), typeof(Main.##441.θᵢ), typeof(ClimateMachine.Ocean.OceanProblems.resting)}(Main.##441.uᵢ, Main.##441.vᵢ, Main.##441.θᵢ, ClimateMachine.Ocean.OceanProblems.resting)

# %% [markdown]
# # Model configuration
#
# We choose a time-step that resolves the gravity wave phase speed,

# %%
time_step = 0.005 # close to Δx / c = 0.5 * 1/16, where Δx is nominal resolution
# Out:
# 0.005

# %% [markdown]
# and build a model with a smidgeon of viscosity and diffusion,

# %%
using ClimateMachine.Ocean: HydrostaticBoussinesqSuperModel

model = HydrostaticBoussinesqSuperModel(
    domain = domain,
    time_step = time_step,
    initial_conditions = initial_conditions,
    parameters = NonDimensionalParameters(),
    turbulence_closure = (νʰ = 1e-6, νᶻ = 1e-6, κʰ = 1e-6, κᶻ = 1e-6),
    coriolis = (f₀ = f, β = 0),
    buoyancy = (αᵀ = αᵀ,),
    boundary_tags = ((1, 1), (1, 1), (1, 2)),
);
nothing
# Out:
# ┌ Info: Initializing
# └ @ ClimateMachine /central/scratch/climaci/climatemachine-docs/1212/climatemachine-docs/src/Driver/solver_configs.jl:169

# %% [markdown]
# # Fetching data for an animation
#
# To animate the `ClimateMachine.Ocean` solution, we assemble and
# cache the horizontal velocity ``u`` at periodic intervals:

# %%
using ClimateMachine.Ocean: current_time
using ClimateMachine.Ocean.Fields: assemble
using ClimateMachine.GenericCallbacks: EveryXSimulationTime

fetched_states = []
fetch_every = 0.2 * 2π / ω # time

data_fetcher = EveryXSimulationTime(fetch_every) do
    push!(
        fetched_states,
        (
            u = assemble(model.fields.u.elements),
            θ = assemble(model.fields.θ.elements),
            η = assemble(model.fields.η.elements),
            time = current_time(model),
        ),
    )
    return nothing
end
# Out:
# ClimateMachine.GenericCallbacks.EveryXSimulationTime(Main.##441.var"#1#2"(), 0.46670328817831874, 0)

# %% [markdown]
# We also build a callback to log the progress of our simulation,

# %%
using Printf
using ClimateMachine.GenericCallbacks: EveryXSimulationSteps
using ClimateMachine.Ocean: current_time, current_step, Δt

print_every = 100 # iterations
wall_clock = [time_ns()]

tiny_progress_printer = EveryXSimulationSteps(print_every) do

    @info(@sprintf(
        "Steps: %d, time: %.2f, Δt: %.2f, max(|u|): %.2e, elapsed time: %.2f secs",
        current_step(model),
        current_time(model),
        Δt(model),
        maximum(abs, model.fields.u),
        1e-9 * (time_ns() - wall_clock[1])
    ))

    wall_clock[1] = time_ns()
end
# Out:
# ClimateMachine.GenericCallbacks.EveryXSimulationSteps(Main.##441.var"#3#4"(), 100, 0)

# %% [markdown]
# # Running the simulation and animating the results
#
# We're ready to launch.

# %%
model.solver_configuration.timeend = 6 * 2π / ω
# model.solver.dt = 0.05 # make this work

@info """ Simulating a hydrostatic Gaussian wave packet with parameters

    f (Coriolis parameter):       $f
    N (buoyancy frequency):       $N
    Internal wave frequency:      $(abs(ω))
    Surface wave frequency:       $(k * sqrt(g * domain.L.z))
    Surface wave group velocity:  $(sqrt(g * domain.L.z))
    Internal wave group velocity: $(N^2 * k / (ω * m))
    Domain width:                 $(domain.L.x)
    Domain height:                $(domain.L.z)

"""

result = ClimateMachine.invoke!(
    model.solver_configuration;
    user_callbacks = [tiny_progress_printer, data_fetcher],
)
# Out:
# ┌ Info:  Simulating a hydrostatic Gaussian wave packet with parameters
# │
# │     f (Coriolis parameter):       1
# │     N (buoyancy frequency):       10
# │     Internal wave frequency:      2.692582403567252
# │     Surface wave frequency:       12.566370614359172
# │     Surface wave group velocity:  16.0
# │     Internal wave group velocity: 9.284766908852594
# │     Domain width:                 256.0
# │     Domain height:                1.0
# │
# └ @ Main.##441 string:4
# ┌ Info: Starting
# │     dt              = 5.00000e-03
# │     timeend         =    14.00
# │     number of steps = 1
# │     norm(Q)         = 1.4780166891254394e+04
# └ @ ClimateMachine /central/scratch/climaci/climatemachine-docs/1212/climatemachine-docs/src/Driver/Driver.jl:802
# ┌ Info: Steps: 100, time: 0.50, Δt: 0.01, max(|u|): 2.54e-07, elapsed time: 45.64 secs
# └ @ Main.##441 string:10
# ┌ Info: Steps: 200, time: 1.00, Δt: 0.01, max(|u|): 1.54e-07, elapsed time: 1.97 secs
# └ @ Main.##441 string:10
# ┌ Info: Steps: 300, time: 1.50, Δt: 0.01, max(|u|): 2.56e-07, elapsed time: 1.66 secs
# └ @ Main.##441 string:10
# ┌ Info: Steps: 400, time: 2.00, Δt: 0.01, max(|u|): 1.23e-07, elapsed time: 1.65 secs
# └ @ Main.##441 string:10
# ┌ Info: Steps: 500, time: 2.50, Δt: 0.01, max(|u|): 1.10e-07, elapsed time: 1.64 secs
# └ @ Main.##441 string:10
# ┌ Info: Steps: 600, time: 3.00, Δt: 0.01, max(|u|): 1.04e-07, elapsed time: 2.03 secs
# └ @ Main.##441 string:10
# ┌ Info: Steps: 700, time: 3.50, Δt: 0.01, max(|u|): 1.19e-07, elapsed time: 1.68 secs
# └ @ Main.##441 string:10
# ┌ Info: Steps: 800, time: 4.00, Δt: 0.01, max(|u|): 8.99e-08, elapsed time: 1.69 secs
# └ @ Main.##441 string:10
# ┌ Info: Steps: 900, time: 4.50, Δt: 0.01, max(|u|): 1.28e-07, elapsed time: 1.69 secs
# └ @ Main.##441 string:10
# ┌ Info: Update
# │     simtime =     4.69 /    14.00
# │     wallclock = 00:01:00
# │     efficiency (simtime / wallclock) =   0.0782
# │     wallclock end (estimated) = 00:02:59
# │     norm(Q) = 1.4779957058997892e+04
# └ @ ClimateMachine.Callbacks /central/scratch/climaci/climatemachine-docs/1212/climatemachine-docs/src/Driver/Callbacks/Callbacks.jl:75
# ┌ Info: Steps: 1000, time: 5.00, Δt: 0.01, max(|u|): 1.39e-07, elapsed time: 1.97 secs
# └ @ Main.##441 string:10
# ┌ Info: Steps: 1100, time: 5.50, Δt: 0.01, max(|u|): 1.26e-07, elapsed time: 1.71 secs
# └ @ Main.##441 string:10
# ┌ Info: Steps: 1200, time: 6.00, Δt: 0.01, max(|u|): 1.03e-07, elapsed time: 1.74 secs
# └ @ Main.##441 string:10
# ┌ Info: Steps: 1300, time: 6.50, Δt: 0.01, max(|u|): 6.65e-08, elapsed time: 1.71 secs
# └ @ Main.##441 string:10
# ┌ Info: Steps: 1400, time: 7.00, Δt: 0.01, max(|u|): 1.37e-07, elapsed time: 1.71 secs
# └ @ Main.##441 string:10
# ┌ Info: Steps: 1500, time: 7.50, Δt: 0.01, max(|u|): 8.29e-08, elapsed time: 1.66 secs
# └ @ Main.##441 string:10
# ┌ Info: Steps: 1600, time: 8.00, Δt: 0.01, max(|u|): 7.20e-08, elapsed time: 1.68 secs
# └ @ Main.##441 string:10
# ┌ Info: Steps: 1700, time: 8.50, Δt: 0.01, max(|u|): 7.33e-08, elapsed time: 1.59 secs
# └ @ Main.##441 string:10
# ┌ Info: Steps: 1800, time: 9.00, Δt: 0.01, max(|u|): 1.09e-07, elapsed time: 1.60 secs
# └ @ Main.##441 string:10
# ┌ Info: Steps: 1900, time: 9.50, Δt: 0.01, max(|u|): 7.96e-08, elapsed time: 1.58 secs
# └ @ Main.##441 string:10
# ┌ Info: Steps: 2000, time: 10.00, Δt: 0.01, max(|u|): 9.98e-08, elapsed time: 1.59 secs
# └ @ Main.##441 string:10
# ┌ Info: Steps: 2100, time: 10.50, Δt: 0.01, max(|u|): 8.89e-08, elapsed time: 1.64 secs
# └ @ Main.##441 string:10
# ┌ Info: Steps: 2200, time: 11.00, Δt: 0.01, max(|u|): 1.17e-07, elapsed time: 1.61 secs
# └ @ Main.##441 string:10
# ┌ Info: Steps: 2300, time: 11.50, Δt: 0.01, max(|u|): 1.06e-07, elapsed time: 1.67 secs
# └ @ Main.##441 string:10
# ┌ Info: Steps: 2400, time: 12.00, Δt: 0.01, max(|u|): 7.91e-08, elapsed time: 1.65 secs
# └ @ Main.##441 string:10
# ┌ Info: Steps: 2500, time: 12.50, Δt: 0.01, max(|u|): 1.06e-07, elapsed time: 1.64 secs
# └ @ Main.##441 string:10
# ┌ Info: Steps: 2600, time: 13.00, Δt: 0.01, max(|u|): 7.81e-08, elapsed time: 1.73 secs
# └ @ Main.##441 string:10
# ┌ Info: Steps: 2700, time: 13.50, Δt: 0.01, max(|u|): 8.66e-08, elapsed time: 1.69 secs
# └ @ Main.##441 string:10
# ┌ Info: Steps: 2800, time: 14.00, Δt: 0.01, max(|u|): 7.43e-08, elapsed time: 1.73 secs
# └ @ Main.##441 string:10
# ┌ Info: Finished
# │     norm(Q)            = 1.4779539437004438e+04
# │     norm(Q) / norm(Q₀) = 9.9995754755311139e-01
# │     norm(Q) - norm(Q₀) = -6.2745424995591748e-01
# └ @ ClimateMachine /central/scratch/climaci/climatemachine-docs/1212/climatemachine-docs/src/Driver/Driver.jl:853
# 0.9999575475531114

# %% [markdown]
# # Animating the result
#
# We first analye the results to generate plotting limits and contour levels

# %%
ηmax = maximum([maximum(abs, state.η.data) for state in fetched_states])
umax = maximum([maximum(abs, state.u.data) for state in fetched_states])

ηlim = (-ηmax, ηmax)
ulim = (-umax, umax)
ulevels = range(ulim[1], ulim[2], length = 31)
# Out:
# -2.2110987494544655e-7:1.4740658329696437e-8:2.2110987494544655e-7

# %% [markdown]
# and then animate both fields in a loop,

# %%
using Plots

animation = @animate for (i, state) in enumerate(fetched_states)
    @info "Plotting frame $i of $(length(fetched_states))..."

    η_plot = plot(
        state.u.x[:, 1, 1],
        state.η.data[:, 1, 1],
        ylim = ηlim,
        label = nothing,
        title = @sprintf("η at t = %.2f", state.time),
    )

    u_plot = contourf(
        state.u.x[:, 1, 1],
        state.u.z[1, 1, :],
        clamp.(state.u.data[:, 1, :], ulim[1], ulim[2])';
        aspectratio = 64,
        linewidth = 0,
        xlim = domain.x,
        ylim = domain.z,
        xlabel = "x",
        ylabel = "z",
        color = :balance,
        colorbar = false,
        clim = ulim,
        levels = ulevels,
        title = @sprintf("u at t = %.2f", state.time),
    )

    plot(
        η_plot,
        u_plot,
        layout = Plots.grid(2, 1, heights = (0.3, 0.7)),
        link = :x,
        size = (600, 300),
    )
end

gif(animation, "internal_wave.mp4", fps = 5) # hide
# Out:
# ┌ Info: Plotting frame 1 of 29...
# └ @ Main.##441 string:4
# ┌ Info: Plotting frame 2 of 29...
# └ @ Main.##441 string:4
# ┌ Info: Plotting frame 3 of 29...
# └ @ Main.##441 string:4
# ┌ Info: Plotting frame 4 of 29...
# └ @ Main.##441 string:4
# ┌ Info: Plotting frame 5 of 29...
# └ @ Main.##441 string:4
# ┌ Info: Plotting frame 6 of 29...
# └ @ Main.##441 string:4
# ┌ Info: Plotting frame 7 of 29...
# └ @ Main.##441 string:4
# ┌ Info: Plotting frame 8 of 29...
# └ @ Main.##441 string:4
# ┌ Info: Plotting frame 9 of 29...
# └ @ Main.##441 string:4
# ┌ Info: Plotting frame 10 of 29...
# └ @ Main.##441 string:4
# ┌ Info: Plotting frame 11 of 29...
# └ @ Main.##441 string:4
# ┌ Info: Plotting frame 12 of 29...
# └ @ Main.##441 string:4
# ┌ Info: Plotting frame 13 of 29...
# └ @ Main.##441 string:4
# ┌ Info: Plotting frame 14 of 29...
# └ @ Main.##441 string:4
# ┌ Info: Plotting frame 15 of 29...
# └ @ Main.##441 string:4
# ┌ Info: Plotting frame 16 of 29...
# └ @ Main.##441 string:4
# ┌ Info: Plotting frame 17 of 29...
# └ @ Main.##441 string:4
# ┌ Info: Plotting frame 18 of 29...
# └ @ Main.##441 string:4
# ┌ Info: Plotting frame 19 of 29...
# └ @ Main.##441 string:4
# ┌ Info: Plotting frame 20 of 29...
# └ @ Main.##441 string:4
# ┌ Info: Plotting frame 21 of 29...
# └ @ Main.##441 string:4
# ┌ Info: Plotting frame 22 of 29...
# └ @ Main.##441 string:4
# ┌ Info: Plotting frame 23 of 29...
# └ @ Main.##441 string:4
# ┌ Info: Plotting frame 24 of 29...
# └ @ Main.##441 string:4
# ┌ Info: Plotting frame 25 of 29...
# └ @ Main.##441 string:4
# ┌ Info: Plotting frame 26 of 29...
# └ @ Main.##441 string:4
# ┌ Info: Plotting frame 27 of 29...
# └ @ Main.##441 string:4
# ┌ Info: Plotting frame 28 of 29...
# └ @ Main.##441 string:4
# ┌ Info: Plotting frame 29 of 29...
# └ @ Main.##441 string:4
# ┌ Info: Saved animation to
# │   fn = /central/scratch/climaci/climatemachine-docs/1212/climatemachine-docs/docs/src/generated/Ocean/internal_wave.mp4
# └ @ Plots /central/scratch/climaci/climatemachine-docs/1212/depot/cpu/packages/Plots/z5Msu/src/animation.jl:104
# Plots.AnimatedGif("/central/scratch/climaci/climatemachine-docs/1212/climatemachine-docs/docs/src/generated/Ocean/internal_wave.mp4")

# %% [markdown]
# ---
#
# *This notebook was generated using [Literate.jl](https://github.com/fredrikekre/Literate.jl).*
